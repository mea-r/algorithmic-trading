# %% [markdown]
# Download daily price data

# %%
import yfinance as yf
tickers = ["SPY", "TSLA", "QUBT", "IBM", "PLUG", "NOW", "RHM.DE", "NVDA", "AAPL", "AMZN"]
data = yf.download(tickers, start = "2015-01-01", end = "2025-01-01")
data.to_csv("raw.csv")
# Out:
# /var/folders/6g/nx59r1fd6wn2b89tj274kp300000gn/T/ipykernel_58244/1535301491.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(tickers, start = "2015-01-01", end = "2025-01-01")
# [*********************100%***********************]  10 of 10 completed
