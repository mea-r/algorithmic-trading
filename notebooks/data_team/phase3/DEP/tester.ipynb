# %%
import pandas as pd


df = pd.read_parquet("5_year_ticker_headlines.parquet")

df_rating = pd.read_parquet("5_year_ticker_headlines_with_finbert_rating.parquet")
df_rating.sort_index(inplace = True, level = 0, ascending = True, sort_remaining = False)

df_ratings_calculated = pd.read_parquet("5_year_ticker_headlines_with_finbert_rating_calculated_final.parquet")



print(df_rating.loc["SHOP"])
#print(df_ratings_calculated.loc["AAPL"])

#print(df_rating.loc["AAPL", "2026-04-23 23:26:37", "6c76c88e"]["Headline"])



#print(df_rating.loc["AAPL"].xs("2026-04-19", level = 0, drop_level = False)[["pos", "neg"]])

#print(df)

#print(df_rating.loc["JPM", "2026-04-23 23:39:59", "f2e2a2b8"]["Headline"])
#print(df_rating.loc["NKE", "2026-04-23 23:39:59", "df227634"]["Headline"])


#df.to_csv("5_year_ticker_headlines.csv", index = False, encoding = "utf-8-sig")



#print(df[(df["Ticker"] == "SPY") & (df["Headline"] >= "2022-09-30 00:00:00") & (df["Timestamp"] <= "2022-10-01 00:00:00")])
#print(df[(df["Ticker"] == "CVX") & (df["HeadlineID"] == "07c8365d")]) #& (df["Timestamp"] <= "2022-10-01 00:00:00")])
# Out:
#                                                                          Headline  \
# Timestamp           HeadlineID
# 2026-04-22 21:10:12 a29c3ea9    Automatic Securities Disposition Plans Adopted...
# 2026-04-21 12:39:06 3fbf7b5c    JPMorgan Sees Shopify Growth Holding Up Across...
# 2026-04-19 12:09:30 5afbe06d    Why Shopify (SHOP) Is Up 18.4% After Avenue Z ...
# 2026-04-17 23:08:55 3a6e266e    SHOP Forecast, Price Target & Analyst Ratings ...
# 2026-04-16 23:10:12 b237c2b0       Shopify, Inc. Class A Trade Ideas — BSESOF:307
# ...                                                                           ...
# 2021-07-28 11:59:00 9d6e3620    Shopify revenue tops $1B as pandemic causes on...
# 2021-07-24 21:12:09 69001624    Tobi Lutke becomes Canada’s wealthiest company...
# 2021-07-14 21:12:09 f333c471    Class Action Settlement against Bombas and Sho...
# 2021-05-26 21:12:09 55206eee             Behind the Brand With Harley Finkelstein
# 2021-04-28 21:12:09 1a561db8    Shopify Announces First-Quarter 2021 Financial...
#
#                                                          Source       pos  \
# Timestamp           HeadlineID
# 2026-04-22 21:10:12 a29c3ea9                            Shopify  0.037726
# 2026-04-21 12:39:06 3fbf7b5c                               Sahm  0.950925
# 2026-04-19 12:09:30 5afbe06d                               Sahm  0.955440
# 2026-04-17 23:08:55 3a6e266e                          ChartMill  0.041140
# 2026-04-16 23:10:12 b237c2b0    TradingView — Track All Markets  0.030803
# ...                                                         ...       ...
# 2021-07-28 11:59:00 9d6e3620                                CBC  0.928429
# 2021-07-24 21:12:09 69001624                 The Globe and Mail  0.524234
# 2021-07-14 21:12:09 f333c471                   Law Street Media  0.141885
# 2021-05-26 21:12:09 55206eee                            Inc.com  0.046491
# 2021-04-28 21:12:09 1a561db8                            Shopify  0.041312
#
#                                      neu       neg
# Timestamp           HeadlineID
# 2026-04-22 21:10:12 a29c3ea9    0.946809  0.015465
# 2026-04-21 12:39:06 3fbf7b5c    0.031305  0.017769
# 2026-04-19 12:09:30 5afbe06d    0.025092  0.019468
# 2026-04-17 23:08:55 3a6e266e    0.936455  0.022404
# 2026-04-16 23:10:12 b237c2b0    0.942922  0.026275
# ...                                  ...       ...
# 2021-07-28 11:59:00 9d6e3620    0.025254  0.046316
# 2021-07-24 21:12:09 69001624    0.452967  0.022799
# 2021-07-14 21:12:09 f333c471    0.828785  0.029330
# 2021-05-26 21:12:09 55206eee    0.926530  0.026979
# 2021-04-28 21:12:09 1a561db8    0.857448  0.101240
#
# [168 rows x 5 columns]
