# %%
import defeatbeta_api
from defeatbeta_api.data.ticker import Ticker
from defeatbeta_api.data.tickers import Tickers


ticker = Ticker("IONQ")
print(ticker.news().get_news_list()["report_date"].head(5))
# Out:
# 0    2025-03-14
# 1    2025-03-17
# 2    2025-03-31
# 3    2025-04-04
# 4    2025-05-07
# Name: report_date, dtype: str
