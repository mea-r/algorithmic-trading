# %% [markdown]
# ### **Import libraries**:
# - **Hugging Face** is a platform and library for utilizing machine learning models.
# - **InferenceClient** is a library available on Hugging Face and is primarily used to perform inference – the process of reaching conclusions given a set of inputs.
# - **Transformers** is a Python library created by Hugging Face that allows one to download, manipulate, and run thousands of pretrained, open-source AI models.
# - **Pipeline** is a package within Transformers that simplifies the process of working with advanced AI models.
# - **UUID** is a library that provides a way to generate universally unique identifiers. In this script, it is used to create identifiers for headlines.

# %%
import requests
from huggingface_hub import InferenceClient
from transformers import pipeline
import uuid
import pandas as pd
import numpy as np
from datetime import datetime, timedelta, date
from dateutil.relativedelta import relativedelta
from dateutil.rrule import rrule, DAILY
import random
import sys
import fastparquet
import os
from IPython.display import clear_output
import time

# %% [markdown]
# ### **Create a data frame with ticker, headlineID, headline, article publication date, and article source columns.** ###

# %%
def package(ticker_lst_param):
    df_main = pd.DataFrame(columns = ["Ticker", "HeadlineID", "Headline", "Timestamp", "Source"])
    for element in ticker_lst_param:
        tickers = [element["Ticker"] for i in range(len(element["Headline"]))]
        headline_IDs = [str(uuid.uuid4())[:8] for i in range(len(element["Headline"]))]
        data = {"Ticker" : tickers, "HeadlineID" : headline_IDs, "Headline" : element["Headline"], 
                "Timestamp" : element["Timestamp"], "Source" : element["Source"]}
        df = pd.DataFrame(data = data)
        df_main = pd.concat([df_main, df])
    return df_main

# %% [markdown]
# ### **Use the Alpha Vantage API to pull news associated with each ticker.**
#
# ### **To modify the tickers used, make changes to tickers.txt**

# %%
def get_data(txt_file_containing_tickers, collection_start_date, collection_end_date, article_limit_per_day):
    with open(txt_file_containing_tickers, "r") as f:
        tickers = f.readline()
        tickers = tickers[1:-1]
        tickers = tickers.replace('"', "")
        tickers = tickers.split(",")
        tickers = [element.strip() for element in tickers]
    
    with open("api_keys/alpha_vantage.txt", "r") as f:
        alpha_vantage_api_key = f.readline().strip()

    limit = 50
    headline_data = []

    days = collection_end_date.day - collection_start_date.day + 1
    total = len(tickers) * days
    counter = 1
    
    for ticker in tickers:
        for day in rrule(DAILY, dtstart=collection_start_date, until=collection_end_date):

            #print(day)
            
            time_from, time_to = day, day + timedelta(days = 1)
            time_from, time_to = time_from.strftime("%Y%m%dT%H%M"), time_to.strftime("%Y%m%dT%H%M")
            url = f"https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers={ticker}&time_from={time_from}&time_to={time_to}&limit={limit}&apikey={alpha_vantage_api_key}"
            response = requests.get(url)
            data = response.json()

            try:
                news = data["feed"]
            except:
                print(data)
            
            headlines = [article["title"] for article in news]
            
            timestamps = [article["time_published"] for article in news]
            timestamps = [pd.to_datetime(timestamp, format = "mixed") for timestamp in timestamps]
            sources = [article["source"] for article in news]

            headlines_no_dupe, timestamps_no_dupe, sources_no_dupe = [], [], []


            for headline, timestamp, source in zip(headlines, timestamps, sources):
                if headline not in headlines_no_dupe:
                    headlines_no_dupe.append(headline)
                    timestamps_no_dupe.append(timestamp)
                    sources_no_dupe.append(source)


            headlines_no_dupe_limited, timestamps_no_dupe_limited, sources_no_dupe_limited = [], [], []

            if len(headlines_no_dupe) > 25:
                indexes_to_remove = random.sample(range(0, len(headlines_no_dupe)), len(headlines_no_dupe) - article_limit_per_day)
            else:
                indexes_to_remove = []
            for headline, timestamp, source in zip(headlines_no_dupe, timestamps_no_dupe, sources_no_dupe):
                if headlines_no_dupe.index(headline) not in indexes_to_remove:
                    headlines_no_dupe_limited.append(headline)
                    timestamps_no_dupe_limited.append(timestamp)
                    sources_no_dupe_limited.append(source)
            
            headline_datum = {"Ticker" : ticker, "Headline" : headlines_no_dupe_limited, 
                              "Timestamp" : timestamps_no_dupe_limited, "Source" : sources_no_dupe_limited}
            
            headline_data.append(headline_datum)

            print(str(round((counter/total)*100, 2)) + "% complete.", counter, " API calls.")
            counter +=1
            time.sleep(0.55)

    headline_data_packaged = package(headline_data)

    return headline_data_packaged

# %% [markdown]
# ### **Utilize FinBERT - a pre-trained NLP model specialized for financial sentiment analysis – adapted by ProsusAI to analyze the probabilities (positive/negative/neutral) associated with each headline.**

# %%
def add_probabilities(ticker_news_data_df_param, api_key_param):
    pipe = pipeline("text-classification", model="ProsusAI/finbert")
    client = InferenceClient(provider="hf-inference", api_key=api_key_param)
    ticker_news_data_df_param[["pos", "neu", "neg"]] = 0.0, 0.0, 0.0
    ticker_news_data_df_param["Timestamp"] = pd.to_datetime(ticker_news_data_df_param["Timestamp"])
    rows_num, row_counter = len(ticker_news_data_df_param), 1

    for index, row in ticker_news_data_df_param.iterrows():
        headline = row["Headline"]
        result = client.text_classification(headline, model="ProsusAI/finbert")
        for probability in result:
            row = row.copy()
            match probability["label"]:
                case "positive":
                    ticker_news_data_df_param.loc[index, "pos"] = probability.score
                case "neutral":
                    ticker_news_data_df_param.loc[index, "neu"] = probability.score
                case "negative":
                    ticker_news_data_df_param.loc[index, "neg"] = probability.score
        
        clear_output()
        print(str(round((row_counter/rows_num)*100, 2)) + "% complete.")
        row_counter +=1
        time.sleep(0.2)

    ticker_news_data_df_param.set_index(["Ticker", "Timestamp", "HeadlineID"], inplace = True)
    ticker_news_data_df_param.sort_index(inplace = True, level = 0)
    ticker_news_data_df_param.sort_index(inplace = True, level = 1, ascending = False, sort_remaining = False)
    return ticker_news_data_df_param

# %% [markdown]
# ### **Main program used to collectively execute the whole script and retrieve the API key used for the inference package.**

# %%
def main():
    startTime = datetime.now()
    with open("api_keys/huggingface.txt", "r") as f:
        huggingface_api_key = f.readline().strip()

    collection_start_date = date(2026, 3, 9) #- relativedelta(years = 5)
    collection_end_date = date(2026, 3, 11)

    headline_data_df = get_data("tickers.txt", collection_start_date, collection_end_date, article_limit_per_day = 25)

    #print(headline_data_df)
    headline_data_df.to_csv("total.csv")
    
    #print(headline_data_df[headline_data_df["Ticker"] == "WMT"])
    
    #ticker_news_data_df_with_probabilities = add_probabilities(headline_data_df, huggingface_api_key)

    #print(ticker_news_data_df_with_probabilities)

    print(datetime.now() - startTime)
    
main()
# Out:
# 0.67% complete. 1  API calls.
# 1.33% complete. 2  API calls.
# 2.0% complete. 3  API calls.
# 2.67% complete. 4  API calls.
# 3.33% complete. 5  API calls.
# 4.0% complete. 6  API calls.
# 4.67% complete. 7  API calls.
# 5.33% complete. 8  API calls.
# 6.0% complete. 9  API calls.
# 6.67% complete. 10  API calls.
# 7.33% complete. 11  API calls.
# 8.0% complete. 12  API calls.
# 8.67% complete. 13  API calls.
# 9.33% complete. 14  API calls.
# 10.0% complete. 15  API calls.
# 10.67% complete. 16  API calls.
# 11.33% complete. 17  API calls.
# 12.0% complete. 18  API calls.
# 12.67% complete. 19  API calls.
# 13.33% complete. 20  API calls.
# 14.0% complete. 21  API calls.
# 14.67% complete. 22  API calls.
# 15.33% complete. 23  API calls.
# 16.0% complete. 24  API calls.
# 16.67% complete. 25  API calls.
# 17.33% complete. 26  API calls.
# 18.0% complete. 27  API calls.
# 18.67% complete. 28  API calls.
# 19.33% complete. 29  API calls.
# 20.0% complete. 30  API calls.
# 20.67% complete. 31  API calls.
# 21.33% complete. 32  API calls.
# 22.0% complete. 33  API calls.
# 22.67% complete. 34  API calls.
# 23.33% complete. 35  API calls.
# 24.0% complete. 36  API calls.
# 24.67% complete. 37  API calls.
# 25.33% complete. 38  API calls.
# 26.0% complete. 39  API calls.
# 26.67% complete. 40  API calls.
# 27.33% complete. 41  API calls.
# 28.0% complete. 42  API calls.
# 28.67% complete. 43  API calls.
# 29.33% complete. 44  API calls.
# 30.0% complete. 45  API calls.
# 30.67% complete. 46  API calls.
# 31.33% complete. 47  API calls.
# 32.0% complete. 48  API calls.
# 32.67% complete. 49  API calls.
# 33.33% complete. 50  API calls.
# 34.0% complete. 51  API calls.
# 34.67% complete. 52  API calls.
# 35.33% complete. 53  API calls.
# 36.0% complete. 54  API calls.
# 36.67% complete. 55  API calls.
# 37.33% complete. 56  API calls.
# 38.0% complete. 57  API calls.
# 38.67% complete. 58  API calls.
# 39.33% complete. 59  API calls.
# 40.0% complete. 60  API calls.
# 40.67% complete. 61  API calls.
# 41.33% complete. 62  API calls.
# 42.0% complete. 63  API calls.
# 42.67% complete. 64  API calls.
# 43.33% complete. 65  API calls.
# 44.0% complete. 66  API calls.
# 44.67% complete. 67  API calls.
# 45.33% complete. 68  API calls.
# 46.0% complete. 69  API calls.
# 46.67% complete. 70  API calls.
# 47.33% complete. 71  API calls.
# 48.0% complete. 72  API calls.
# 48.67% complete. 73  API calls.
# 49.33% complete. 74  API calls.
# 50.0% complete. 75  API calls.
# 50.67% complete. 76  API calls.
# 51.33% complete. 77  API calls.
# 52.0% complete. 78  API calls.
# 52.67% complete. 79  API calls.
# 53.33% complete. 80  API calls.
# 54.0% complete. 81  API calls.
# 54.67% complete. 82  API calls.
# 55.33% complete. 83  API calls.
# 56.0% complete. 84  API calls.
# 56.67% complete. 85  API calls.
# 57.33% complete. 86  API calls.
# 58.0% complete. 87  API calls.
# 58.67% complete. 88  API calls.
# 59.33% complete. 89  API calls.
# 60.0% complete. 90  API calls.
# 60.67% complete. 91  API calls.
# 61.33% complete. 92  API calls.
# 62.0% complete. 93  API calls.
# 62.67% complete. 94  API calls.
# 63.33% complete. 95  API calls.
# 64.0% complete. 96  API calls.
# 64.67% complete. 97  API calls.
# 65.33% complete. 98  API calls.
# 66.0% complete. 99  API calls.
# 66.67% complete. 100  API calls.
# 67.33% complete. 101  API calls.
# 68.0% complete. 102  API calls.
# 68.67% complete. 103  API calls.
# 69.33% complete. 104  API calls.
# 70.0% complete. 105  API calls.
# 70.67% complete. 106  API calls.
# 71.33% complete. 107  API calls.
# 72.0% complete. 108  API calls.
# 72.67% complete. 109  API calls.
# 73.33% complete. 110  API calls.
# 74.0% complete. 111  API calls.
# 74.67% complete. 112  API calls.
# 75.33% complete. 113  API calls.
# 76.0% complete. 114  API calls.
# 76.67% complete. 115  API calls.
# 77.33% complete. 116  API calls.
# 78.0% complete. 117  API calls.
# 78.67% complete. 118  API calls.
# 79.33% complete. 119  API calls.
# 80.0% complete. 120  API calls.
# 80.67% complete. 121  API calls.
# 81.33% complete. 122  API calls.
# 82.0% complete. 123  API calls.
# 82.67% complete. 124  API calls.
# 83.33% complete. 125  API calls.
# 84.0% complete. 126  API calls.
# 84.67% complete. 127  API calls.
# 85.33% complete. 128  API calls.
# 86.0% complete. 129  API calls.
# 86.67% complete. 130  API calls.
# 87.33% complete. 131  API calls.
# 88.0% complete. 132  API calls.
# 88.67% complete. 133  API calls.
# 89.33% complete. 134  API calls.
# 90.0% complete. 135  API calls.
# 90.67% complete. 136  API calls.
# 91.33% complete. 137  API calls.
# 92.0% complete. 138  API calls.
# 92.67% complete. 139  API calls.
# 93.33% complete. 140  API calls.
# 94.0% complete. 141  API calls.
# 94.67% complete. 142  API calls.
# 95.33% complete. 143  API calls.
# 96.0% complete. 144  API calls.
# 96.67% complete. 145  API calls.
# 97.33% complete. 146  API calls.
# 98.0% complete. 147  API calls.
# 98.67% complete. 148  API calls.
# 99.33% complete. 149  API calls.
# 100.0% complete. 150  API calls.
# 0:02:10.716265
