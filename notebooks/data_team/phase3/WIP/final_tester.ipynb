# %%
import pandas as pd




df = pd.read_parquet("5_year_ticker_headlines_with_finbert_rating_calculated.parquet")

print(df)
# Out:
#                             sent_mean  sent_std  news_count  \
# Ticker Timestamp
# AMD    2026-04-23 23:39:59        NaN       NaN         NaN
#        2026-04-23 23:39:22        NaN       NaN         NaN
#        2026-04-23 23:26:37        NaN       NaN         NaN
#        2026-04-23 23:24:59        NaN       NaN         NaN
#        2026-04-23 23:15:55        NaN       NaN         NaN
# ...                               ...       ...         ...
# AMZN   2021-04-23 13:00:00        NaN       NaN         NaN
#        2021-04-23 11:15:57        NaN       NaN         NaN
#        2021-04-23 11:05:00        NaN       NaN         NaN
#        2021-04-23 09:43:00        NaN       NaN         NaN
#        2021-04-23 08:00:00        NaN       NaN         NaN
#
#                             pct_strong_negative  sent_momentum
# Ticker Timestamp
# AMD    2026-04-23 23:39:59                  NaN            NaN
#        2026-04-23 23:39:22                  NaN            NaN
# ...
