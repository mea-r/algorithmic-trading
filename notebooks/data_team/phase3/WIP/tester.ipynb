# %%
import pandas as pd


df = pd.read_parquet("5_year_ticker_headlines.parquet")

df_rating = pd.read_parquet("5_year_ticker_headlines_with_finbert_rating.parquet")
df_rating.sort_index(inplace = True, level = 0, ascending = True, sort_remaining = False)

df_ratings_calculated = pd.read_parquet("5_year_ticker_headlines_with_finbert_rating_calculated.parquet")



print(df_ratings_calculated)
#print(df_ratings_calculated.loc["AAPL"])

#print(df_rating.loc["AAPL", "2026-04-23 23:26:37", "6c76c88e"]["Headline"])



#print(df_rating.loc["AAPL"].xs("2026-04-19", level = 0, drop_level = False)[["pos", "neg"]])

#print(df)

#print(df_rating.loc["JPM", "2026-04-23 23:39:59", "f2e2a2b8"]["Headline"])
#print(df_rating.loc["NKE", "2026-04-23 23:39:59", "df227634"]["Headline"])


#df.to_csv("5_year_ticker_headlines.csv", index = False, encoding = "utf-8-sig")



#print(df[(df["Ticker"] == "SPY") & (df["Headline"] >= "2022-09-30 00:00:00") & (df["Timestamp"] <= "2022-10-01 00:00:00")])
#print(df[(df["Ticker"] == "CVX") & (df["HeadlineID"] == "07c8365d")]) #& (df["Timestamp"] <= "2022-10-01 00:00:00")])
# Out:
#                    sent_mean  sent_std  news_count  pct_strong_negative  \
# Ticker Date
# AAPL   2026-04-23   0.134550  0.395870          25                 4.00
#        2026-04-22   0.044053  0.367462          25                 8.00
#        2026-04-21   0.016289  0.450291          25                12.00
#        2026-04-20   0.215415  0.575118          25                12.00
#        2026-04-19   0.224013  0.556474          23                13.04
# ...                      ...       ...         ...                  ...
# XOM    2021-05-14   0.148637  0.168114           2                 0.00
#        2021-05-13   0.147608  0.254766           5                 0.00
#        2021-05-07   0.436348  0.345401           3                 0.00
#        2021-05-01   0.898479  0.000000           1                 0.00
#        2021-04-30  -0.269953  0.646581           5                40.00
#
#                    sent_momentum
# Ticker Date
# AAPL   2026-04-23       0.007686
#        2026-04-22      -0.120960
#        2026-04-21      -0.143801
#        2026-04-20       0.024563
#        2026-04-19       0.068227
# ...                          ...
# XOM    2021-05-14       0.368825
#        2021-05-13       0.380834
#        2021-05-07       0.068880
#        2021-05-01       0.680107
#        2021-04-30      -0.365620
#
# [11110 rows x 5 columns]
